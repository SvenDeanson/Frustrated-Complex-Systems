# %%
import numpy as np
import pulp as plp
import random
import matplotlib.pyplot as plt
import time
import networkx as nx
from tqdm import tqdm
# %matplotlib notebook

# %% [markdown]
# # Medium

# %%
f = open("/home/sven/Desktop/p180_N.txt",'r')

p180 =[]
for line in f:
    if len(line.rstrip("\n"))==1:
            p180.append(0)
    else:
        p180.append(float((line.rstrip("\n")).replace("*^","e")))
p180 = np.array(p180)

p180 = np.delete(p180, -1)


d10 = np.load("/home/sven/Desktop/medium-graph-10.npy")

vals2 = d10[:,0]
errs2 = d10[:,1]

# %%
fig, ax = plt.subplots()#figsize=[8,8])
ax.fill_between([i for i in range(len(vals2))], vals2 - errs2, vals2 + errs2,facecolor="red", alpha=0.25)#, edgecolor="black")
ax.errorbar([i for i in range(len(vals2))],vals2,errs2,capsize=3)
ax.scatter([i for i in range(len(vals2))],vals2,s=10)#,marker="x")
ax.scatter([i for i in range(len(p180))],p180,s=10,c="red")
ax.grid()
ax.set_xlim(60,120)
# Out:
# <img src="data:image/png;base64,..." width="697.5833333333334">
# (60.0, 120.0)

# %%
dat3=np.array([(i,j) for i,j in d10[70:110] if i!=0])
dat4=[i for i in p180[70:110] if i!=0]
vals3 = dat3[:,0]
errs3 = dat3[:,1]

# %%
fig, ax = plt.subplots()#figsize=[8,8])
ax.fill_between([i for i in range(len(vals3))], vals3 - errs3, vals3 + errs3,facecolor="red", alpha=0.25)#, edgecolor="black")
ax.errorbar([i for i in range(len(vals3))],vals3,errs3,capsize=3)
ax.scatter([i for i in range(len(vals3))],vals3,s=10)#,marker="x")
ax.scatter([i for i in range(len(dat4))],dat4,s=10,c="red")
ax.plot([i for i in range(len(dat4))],dat4,c="red")
ax.grid()
#ax.set_xlim(325,425)
# Out:
# <img src="data:image/png;base64,..." width="697.5833333333334">

# %% [markdown]
# ### Less precision

# %%
d10_2 = np.load("/home/sven/Desktop/medium-graph-10-2.npy")

vals2_2 = d10_2[:,0]
errs2_2 = d10_2[:,1]

dat3_2=np.array([(i,j) for i,j in d10_2[70:110] if i!=0])
vals3_2 = dat3_2[:,0]
errs3_2 = dat3_2[:,1]

# %%
fig, ax = plt.subplots()#figsize=[8,8])
"""
ax.fill_between([i for i in range(len(vals2))], vals2 - errs2, vals2 + errs2,facecolor="red", alpha=0.25)#, edgecolor="black")
ax.errorbar([i for i in range(len(vals2))],vals2,errs2,capsize=3)
ax.scatter([i for i in range(len(vals2))],vals2,s=10)#,marker="x")
"""
ax.fill_between([i for i in range(len(vals2_2))], vals2_2 - errs2_2, vals2_2 + errs2_2,facecolor="red", alpha=0.25)#, edgecolor="black")
ax.errorbar([i for i in range(len(vals2_2))],vals2_2,errs2_2,capsize=3)
ax.scatter([i for i in range(len(vals2_2))],vals2_2,s=10)#,marker="x")

ax.scatter([i for i in range(len(p180))],p180,s=10,c="red")

ax.grid()
ax.set_xlim(60,120)
# Out:
# <img src="data:image/png;base64,..." width="697.5833333333334">
# (60.0, 120.0)

# %%
fig, ax = plt.subplots()#figsize=[8,8])

ax.fill_between([i for i in range(len(vals3_2))], vals3_2 - errs3_2, vals3_2 + errs3_2,facecolor="blue", alpha=0.25)#, edgecolor="black")
#ax.errorbar([i for i in range(len(vals3_2))],vals3_2)#,errs3_2,capsize=3)
#ax.scatter([i for i in range(len(vals3_2))],vals3_2,s=10)#,marker="x")

ax.fill_between([i for i in range(len(vals3))], vals3 - errs3, vals3 + errs3,facecolor="orange", alpha=0.5)#, edgecolor="black")
#ax.errorbar([i for i in range(len(vals3))],vals3)#,errs3,capsize=3)
#ax.scatter([i for i in range(len(vals3))],vals3,s=10)#,marker="x")

ax.scatter([i for i in range(len(dat4))],dat4,s=10,c="red")
ax.plot([i for i in range(len(dat4))],dat4,c="red")
ax.grid()
#ax.set_xlim(325,425)
# Out:
# <img src="data:image/png;base64,..." width="697.5833333333334">

# %% [markdown]
# # Large

# %%
f = open("/home/sven/Desktop/p760_N.txt",'r')

p760 =[]
for line in f:
    print(line)
    if len(line.rstrip("\n"))==1:
            p760.append(0)
    else:
        p760.append(float((line.rstrip("\n")).replace("*^","e")))
p760 = np.array(p760)

p760 = np.delete(p760, -1)

d20 = np.load("/home/sven/Desktop/large-graph-20.npy")
values = d20[:,0]
errors = d20[:,1]
# Out:
# 8.058541705589979*^-228
#
# 0.
#
# 1.1621222993631308*^-222
#
# 0.
#
# 4.167704675677254*^-218
#
# 0.
#
# 6.607895763286286*^-214
#
# 0.
#
# 5.8620501786796075*^-210
#
# 0.
#
# 3.310604562509666*^-206
#
# 0.
#
# 1.2914806340206976*^-202
#
# 0.
#
# 3.681747720116678*^-199
#
# 0.
#
# 7.992988009411118*^-196
#
# 0.
#
# 1.363722169042713*^-192
#
# 0.
#
# 1.874511126068507*^-189
#
# 0.
#
# 2.11796519504509*^-186
#
# 0.
#
# 1.9999548218336713*^-183
#
# 0.
#
# 1.600437219554945*^-180
#
# 0.
#
# 1.09830412466759*^-177
#
# 0.
#
# 6.529930563073668*^-175
#
# 0.
#
# 3.3935870583505025*^-172
#
# 0.
#
# 1.5536992319674336*^-169
#
# 0.
#
# 6.310104866867737*^-167
#
# 0.
#
# 2.287421753996988*^-164
#
# 0.
#
# 7.442155269401125*^-162
#
# 0.
#
# 2.1840447504895545*^-159
#
# 0.
#
# 5.807641228411806*^-157
#
# 0.
#
# 1.4050868858568713*^-154
#
# 0.
#
# 3.1046199740702595*^-152
#
# 0.
#
# 6.286631914854143*^-150
#
# 0.
#
# 1.1703504584387672*^-147
#
# 0.
#
# 2.0090052951792718*^-145
#
# 0.
#
# ...

# %%
print(p760)
# Out:
# [8.05854171e-228 0.00000000e+000 1.16212230e-222 0.00000000e+000
#  4.16770468e-218 0.00000000e+000 6.60789576e-214 0.00000000e+000
#  5.86205018e-210 0.00000000e+000 3.31060456e-206 0.00000000e+000
#  1.29148063e-202 0.00000000e+000 3.68174772e-199 0.00000000e+000
#  7.99298801e-196 0.00000000e+000 1.36372217e-192 0.00000000e+000
#  1.87451113e-189 0.00000000e+000 2.11796520e-186 0.00000000e+000
#  1.99995482e-183 0.00000000e+000 1.60043722e-180 0.00000000e+000
#  1.09830412e-177 0.00000000e+000 6.52993056e-175 0.00000000e+000
#  3.39358706e-172 0.00000000e+000 1.55369923e-169 0.00000000e+000
#  6.31010487e-167 0.00000000e+000 2.28742175e-164 0.00000000e+000
#  7.44215527e-162 0.00000000e+000 2.18404475e-159 0.00000000e+000
#  5.80764123e-157 0.00000000e+000 1.40508689e-154 0.00000000e+000
#  3.10461997e-152 0.00000000e+000 6.28663191e-150 0.00000000e+000
#  1.17035046e-147 0.00000000e+000 2.00900530e-145 0.00000000e+000
# ...

# %%
fig, ax = plt.subplots()#figsize=[8,8])

ax.errorbar([i for i in range(len(values))],values,yerr=errors,fmt='o',markersize=3,capsize=3)#,marker="x")
ax.scatter([i for i in range(len(p760))],p760,s=10,c="red")

ax.grid()
ax.set_xlim(325,425)
# Out:
# <img src="data:image/png;base64,..." width="697.5833333333334">
# (325.0, 425.0)

# %%
dat1=np.array([(i,j) for i,j in d20[340:420] if i!=0])
dat2=[i for i in p760[340:420] if i!=0]
vals = dat1[:,0]
errs = dat1[:,1]

# %%
fig, ax = plt.subplots()#figsize=[8,8])
ax.fill_between([i for i in range(len(vals))], vals - errs, vals + errs,facecolor="red", alpha=0.25)#, edgecolor="black")
ax.errorbar([i for i in range(len(vals))],vals,errs,capsize=3)
ax.scatter([i for i in range(len(vals))],vals,s=10)#,marker="x")
ax.scatter([i for i in range(len(dat2))],dat2,s=10,c="red")
ax.plot([i for i in range(len(dat2))],dat2,c="red")
ax.grid()
#ax.set_xlim(325,425)
# Out:
# <img src="data:image/png;base64,..." width="697.5833333333334">

# %% [markdown]
# ### Less precision

# %%
d20_2 = np.load("/home/sven/Desktop/large-graph-20-2.npy")

dat1_2=np.array([(i,j) for i,j in d20_2[340:420] if i!=0])
vals_2 = dat1_2[:,0]
errs_2 = dat1_2[:,1]

# %%
fig, ax = plt.subplots()#figsize=[8,8])

ax.fill_between([i for i in range(len(vals_2))], vals_2 - errs_2, vals_2 + errs_2,facecolor="blue", alpha=0.25)#, edgecolor="black")
#ax.errorbar([i for i in range(len(vals3_2))],vals3_2)#,errs3_2,capsize=3)
#ax.scatter([i for i in range(len(vals3_2))],vals3_2,s=10)#,marker="x")

ax.fill_between([i for i in range(len(vals))], vals - errs, vals + errs,facecolor="orange", alpha=0.5)#, edgecolor="black")
#ax.errorbar([i for i in range(len(vals3))],vals3)#,errs3,capsize=3)
#ax.scatter([i for i in range(len(vals3))],vals3,s=10)#,marker="x")

ax.scatter([i for i in range(len(dat2))],dat2,s=10,c="red")
ax.plot([i for i in range(len(dat2))],dat2,c="red")
ax.grid()
#ax.set_xlim(325,425)
# Out:
# <img src="data:image/png;base64,..." width="697.5833333333334">

# %% [markdown]
# # Larger

# %%
d40 = np.load("/home/sven/Desktop/larger-graph-40.npy")
v40 = d40[:,0]
e40 = d40[:,1]

# %%
f = open("/home/sven/Desktop/p3120_N.txt",'r')

p3120 =[]
for line in f:
    if len(line.rstrip("\n"))==1:
            p3120.append(0)
    else:
        p3120.append(float((line.rstrip("\n")).replace("*^","e").replace("`10.","")))
p3120 = np.array(p3120)

p3120 = np.delete(p3120, -1)

# %%
fig, ax = plt.subplots()#figsize=[8,8])
ax.fill_between([i for i in range(len(v40))], v40 - e40, v40 + e40,facecolor="red", alpha=0.25)#, edgecolor="black")
ax.errorbar([i for i in range(len(v40))],v40,e40,capsize=3)
ax.scatter([i for i in range(len(v40))],v40,s=10)#,marker="x")
ax.scatter([i for i in range(len(p3120))],p3120,s=10,c="red")
ax.plot([i for i in range(len(p3120))],p3120,c="red")
ax.grid()
ax.set_xlim(1475, 1640)
# Out:
# <img src="data:image/png;base64,..." width="697.5833333333334">
# (1475.0, 1640.0)

# %%
r40=np.array([(i,j) for i,j in d40[1475:1640] if i!=0])
vr40 = r40[:,0]
er40 = r40[:,1]

r3120=[i for i in p3120[1475:1640] if i!=0]

# %%
fig, ax = plt.subplots()#figsize=[8,8])

ax.fill_between([i for i in range(len(vr40))], vr40 - er40, vr40 + er40,facecolor="blue", alpha=0.25)#, edgecolor="black")
#ax.errorbar([i for i in range(len(vals3_2))],vals3_2)#,errs3_2,capsize=3)
ax.scatter([i for i in range(len(vr40))],vr40,s=10)#,marker="x")

#ax.fill_between([i for i in range(len(vals))], vals - errs, vals + errs,facecolor="orange", alpha=0.5)#, edgecolor="black")
#ax.errorbar([i for i in range(len(vals3))],vals3)#,errs3,capsize=3)
#ax.scatter([i for i in range(len(vals3))],vals3,s=10)#,marker="x")

ax.scatter([i for i in range(len(r3120))],r3120,s=10,c="red")
ax.plot([i for i in range(len(r3120))],r3120,c="red")
ax.grid()
#ax.set_xlim(325,425)
# Out:
# <img src="data:image/png;base64,..." width="697.5833333333334">

# %%
print(len(r3120),len(vr40))
# Out:
# 82 66

# %% [markdown]
# # MOMENTS

# %%
def calculate_moments(data):
    Y = np.array(data)
    X = np.arange(0, len(Y))

    print(len(Y))

    mean = (X * Y).sum()

    var = ((X**2 * Y).sum()-(X * Y).sum()**2)
    skew = (((X**3 * Y).sum()-3*mean*((X**2 * Y).sum()-mean**2)-mean**3)/(np.sqrt(var)**3))
    kurt = ((X**4 * Y).sum() - 4*mean*((X**3 * Y).sum())+6*mean**2*((X**2 * Y).sum())-3*mean**4)/(var**2) - 3

    print("Sum of probabilites: ",Y.sum())
    print("Expected value: ",mean)
    print("Variance: ", var)
    print("Skewness: ",skew)
    print("Kurtosis: ",kurt)

# %%
calculate_moments(p180)
calculate_moments(vals2)
# Out:
# 180
# Sum of probabilites:  1.0
# Expected value:  89.7493036211699
# Variance:  45.12570028283153
# Skewness:  -2.3361216520880742e-06
# Kurtosis:  -0.011079632911967341
# 180
# Sum of probabilites:  1.0
# Expected value:  89.0684
# Variance:  43.67292144000112
# Skewness:  -0.0001884987260721288
# Kurtosis:  0.014833296438262256

# %%
calculate_moments(p760)
calculate_moments(values)
# Out:
# 760
# Sum of probabilites:  1.0
# Expected value:  379.7498354180382
# Variance:  190.12516479898477
# Skewness:  -6.302799738044714e-08
# Kurtosis:  -0.002629839965006653
# 760
# Sum of probabilites:  1.0
# Expected value:  379.2378
# Variance:  189.14665116000106
# Skewness:  -0.00472773406685372
# Kurtosis:  0.018756469780105256

# %% [markdown]
# # Jensen-Shannon Divergence

# %%
from scipy.spatial.distance import jensenshannon


p = data1
q = np.array([i/1000 for i,j in final])


js_pq = jensenshannon(p, q, base=2)
print('JS(P || Q) Distance: %.3f' % js_pq)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-132-735b5fb82581> in <module>
#       3
#       4 p = data1
# ----> 5 q = np.array([i/1000 for i,j in final])
#       6
#       7
#
# NameError: name 'final' is not defined
